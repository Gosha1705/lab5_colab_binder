# %%
import math
print("Корінь квадратний із 144 =", math.sqrt(144))

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title("sin(x)")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.show()
# Out:
# Корінь квадратний із 144 = 12.0
